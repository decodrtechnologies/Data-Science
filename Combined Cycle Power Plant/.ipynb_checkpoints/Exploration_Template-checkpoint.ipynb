# %% [markdown]
# # Combined Cycle Power Plant Analysis

# %% [markdown]
# In Combined Cycle Power Plant analysis with the given dataset we have sensor data for Temperature (T), Ambient Pressure (AP), Relative Humidity (RH) and Exhaust Vacuum (V) of the power plant which produces the net hourly electrical energy output (EP) of the plant. Use Data Science Techniques to find out patterns from the available data to check which features impact the label most.
#
# A combined cycle power plant (CCPP) is composed of gas turbines (GT), steam turbines (ST) and heat recovery steam generators. In a CCPP, the electricity is generated by gas and steam turbines, which are combined in one cycle, and is transferred from one turbine to another. While the Vacuum is collected from and has the effect on the Steam Turbine, the other three of the ambient variables affect the GT performance.
#
# The Dataset is taken from here – [Combined Cycle Dataset](https://archive.ics.uci.edu/ml/datasets/combined+cycle+power+plant)

# %% [markdown]
# # Steps Involved:
#
# 1. Importing the Library
# 2. Loading the Dataset
# 3. Structure of Dataset
# 4. Data Exploration
#      * Statistics
#      * Heat Map
#      * Feature Plot
# 5. Implementation of Gradient Descent
# 6. Inbuilt Gradient Boosting Regression
# 7. Conclusion

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename='download.png')

# %% [markdown]
# # 1. Importing the Library

# %%
#Import all the required Packages like numpy ,pandas etc.
#Import the library for the plots also

# %% [markdown]
# # 2. Loading the Dataset

# %%
'''Load the dataset of Combine Cycle Power Plant Dataset''';
#There is seprate training and testing file is provided as csv.
#Use the Pandas or numpy to read the file

# %%
'''If the data is taken from the numpy,try to convert it into dataframe ''';

# %%
'''The Last Column, i.e electrical energy output (EP) of the plant is your target value''';
#Print the target value

# %%
#Print the columns names in the dataset

# %%
#Save the target value in some other variable for further analysis
'''Use columns name for this indexing''';

# %% [markdown]
# # 3. Structure of the Dataset

# %%
#Print the shape of the dataset

# %%
#Call the describe function

# %% [markdown]
# ## Missing or Null Points

# %%
#Check for null value in the features using isnull function

# %%
#Check for nan value in the features using isnan function

# %%
'''Check whether you get any null value or nan value''';
#If found try to avoid that, and if not proceed to next step

# %% [markdown]
# # 4. Data Exploration
#
# ## Statistics
# For your very first coding implementation, you will calculate descriptive statistics about the Combined Cycle Power Plant. Since numpy has already been imported for you, use this library to perform the necessary calculations. These statistics will be extremely important later on to analyze various prediction results from the constructed model.
#
# In the code cell below, you will need to implement the following:
#
#  * Calculate the minimum, maximum, mean, median, and standard deviation of 'EP'. Store each calculation in their respective variable.
#  * Store each calculation in their respective variable.

# %%
# TODO: Minimum output of the data

# Alternative using pandas
# minimum_output = prices.min()

# TODO: Maximum output of the data

# Alternative using pandas
# maximum_output = prices.max()

# TODO: Mean EP of the data

# Alternative using pandas
# mean_EP = prices.mean()

# TODO: Median output of the data

# Alternative using pandas
# median_EP = prices.median()

# TODO: Standard deviation of output of the data

# Alternative using pandas 
# std_EP = prices.std(ddof=0)

# There are other statistics you can calculate too like quartiles

# Show the calculated statistics

# %% [markdown]
# After statistics analysis, go for the graphical representation

# %%
#You'll use displot from seaborn on the target value

# %%
'''Get some observation from the above graph and perform the filteration at this level, if you found.''';

# %% [markdown]
# ## Heat Map

# %%
'''Check for Correlation in the Dataset''';

# %%
#Use heat map in the seaborn library to get the correlation graph

# %% [markdown]
# A heat map uses a warm-to-cool color spectrum to show dataset analytics, namely which parts of data receive the most attention.
#
# The correlation coefficient ranges from -1 to 1. If the value is close to 1, it means that there is a strong positive correlation between the two variables. When it is close to -1, the variables have a strong negative correlation.

# %% [markdown]
# **Is there any relations among the features?**

# %%
'''Try to get some correlation from the above graph, and try to use the features 
   only with the more positive correlation and more correlation''';

# %% [markdown]
# An important point in selecting features for a regression model is to check for multi-co-linearity. So the features with the same correlation try to avoid that.

# %% [markdown]
# **Based on above analysis, now you have to perform the filteration the dataset, if you get any relevant.**

# %%
#Create the dataframe with the filteration applied to original

# %% [markdown]
# ## Feature Plot

# %% [markdown]
# Here you'll plot the graph of each features and analysis the data

# %%
#Use pyplot library 
'''Other function that might you can use like .xlable, .ylable, .plot, .show''';

# %%
#Using Seaborn for Better Understanding of the Filter_data Features
'''Use boxplot for the features to get the value range''';

# %% [markdown]
# **Of the features you investigated, were there any unusual distributions?**
#
# Find the answer of the above question, and if you find any outlier try to remove it.
#
# And if everything is fine, proceed with the dataset

# %%
'''If filteration done by the above observation''';
#Save the new Dataframe and change the value of every value to be used accordingly

# %% [markdown]
# # 5. Implementation of Gradient Descent

# %% [markdown]
# You are recommended to write the program in order of their execution for better understanding
#  * run
#  * gradient_descent_runner
#  * step_gradient
#  * compute_error_for_line_given_points

# %%
'''Here you will compute the error for given points in the training dataset'''
def compute_error_for_line_given_points(b, m, points):
    #take totalError inital as zero
    #Iterate till len of points
    #Include x as 0th index of iterator
    #Include y as 1th index of iterator
    #Compute total error and add the new total error
    '''Formula to be used: (y-(m*x+b)))**2'''
    #Return totalError by total len of points

# %%
'''Here you will compute the step_gradient '''
def step_gradient(b_current, m_current, points, learningRate):
    #Intialise two variable one for b and other for m as zero
    #Take variable as length of points
    #Include x as 0th index of iterator
    #Include y as 1th index of iterator
    #Update the new b and new m at every iteration by adding value as per formula given
    #Update new b and new m at last by subtracting the learningRate*new b for b and similarly for m
    '''Formula to be used in iteration:    -(2/N) * (y - ((m_current * x) + b_current)) , similarly for m'''
    """Formula to be used to update in last: new_b = b_current - (learningRate * b_gradient), similarly for m"""
    #Return new_m and new_b

# %%
'''Here you will implement the gradient_descent_runner function'''
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    #Save the starting_b and starting_m in some new variable
    #Iterate over the num_iterations 
    '''Call step_gradient on new_b and new_m'''
    #Save the value return in new_b and new_m
    #Return new_b and new_m

# %%
'''Here you will implement the run function, which is going to call above functions'''
def run():
    #save the training data in some variable,i.e points
    #Use numpy for Importing the Data
    #Intialise the learning_Rate,initial_b,initial_m and num_iterations
    #Print the Starting b,Starting m and Starting Cost
    '''Call gradient_descent_runnner'''
    #Print the New_b, New_m and New_Cost

# %%
'''Call the Run Function''';

# %% [markdown]
# # 6. Inbuilt Gradient Boosting Regression

# %%
#Seperate the X data and Y data from the training Dataset

# %%
#Print the Shape of x_train and y_train

# %% [markdown]
# **Importing the library for Regression**

# %%
#Import the inbuilt library for Gradient Descent 
'''Use sklearn.ensemble''';

# %%
#Call the regression and save the object in some variable

# %% [markdown]
# **Training the Model**

# %% [markdown]
# **Prediction**

# %%
#Read the testing Data

# %%
#Predict the test data and store the result in some variable
'''Use inbuilt .predict function for this''';

# %% [markdown]
# **Model Evaluation**

# %%
#Get the R2 score for the model
'''Use inbuilt score function in the regression model''';

# %% [markdown]
# # 7. Conclusion

# %% [markdown]
# Get some conclusion about the dataset from all the analysis, and also about the Gradient Descent Implementation and Inbuilt
